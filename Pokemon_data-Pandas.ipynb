# %%
# importing the necessary library
import pandas as pd

# %%
#reading pokemon Data

df = pd.read_csv('C:/Users/GREEN LION/Documents/Python Tutorials/Keith Galli - Data Science/pokemon_data.csv')
df.set_index('#',inplace=True)

# %%
#checking first few rows and headers
df.head(20)
# Out:
#                          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                   Bulbasaur  Grass  Poison  45      49       49       65
# 2                     Ivysaur  Grass  Poison  60      62       63       80
# 3                    Venusaur  Grass  Poison  80      82       83      100
# 3       VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                  Charmander   Fire     NaN  39      52       43       60
# 5                  Charmeleon   Fire     NaN  58      64       58       80
# 6                   Charizard   Fire  Flying  78      84       78      109
# 6   CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6   CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 7                    Squirtle  Water     NaN  44      48       65       50
# 8                   Wartortle  Water     NaN  59      63       80       65
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 69.5+ KB

# %%
# Reading Headers

df.columns

# reading only selected columns
df[['Name','Type 1','Legendary']]
# Out:
#                       Name   Type 1  Legendary
# #
# 1                Bulbasaur    Grass      False
# 2                  Ivysaur    Grass      False
# 3                 Venusaur    Grass      False
# 3    VenusaurMega Venusaur    Grass      False
# 4               Charmander     Fire      False
# ..                     ...      ...        ...
# 719                Diancie     Rock       True
# 719    DiancieMega Diancie     Rock       True
# 720    HoopaHoopa Confined  Psychic       True
# 720     HoopaHoopa Unbound  Psychic       True
# 721              Volcanion     Fire       True
#
# [800 rows x 3 columns]

# %%
#reading each column
df.Name[0:20]

df['Type 1'][0:20]
# Out:
# #
# 1     Grass
# 2     Grass
# 3     Grass
# 3     Grass
# 4      Fire
# 5      Fire
# 6      Fire
# 6      Fire
# 6      Fire
# 7     Water
# 8     Water
# 9     Water
# 9     Water
# 10      Bug
# 11      Bug
# 12      Bug
# 13      Bug
# 14      Bug
# 15      Bug
# 15      Bug
# Name: Type 1, dtype: object

# %%
# Reading each row

df.loc[df['Type 1']=='Fire']  # selecting on only fire in type 1
# Out:
#                           Name Type 1    Type 2   HP  Attack  Defense  \
# #
# 4                   Charmander   Fire       NaN   39      52       43
# 5                   Charmeleon   Fire       NaN   58      64       58
# 6                    Charizard   Fire    Flying   78      84       78
# 6    CharizardMega Charizard X   Fire    Dragon   78     130      111
# 6    CharizardMega Charizard Y   Fire    Flying   78     104       78
# 37                      Vulpix   Fire       NaN   38      41       40
# 38                   Ninetales   Fire       NaN   73      76       75
# 58                   Growlithe   Fire       NaN   55      70       45
# 59                    Arcanine   Fire       NaN   90     110       80
# 77                      Ponyta   Fire       NaN   50      85       55
# 78                    Rapidash   Fire       NaN   65     100       70
# 126                     Magmar   Fire       NaN   65      95       57
# ...

# %%
## Sorting/Describing Data

# %%
df.describe().T
# Out:
#             count      mean        std   min    25%   50%    75%    max
# HP          800.0  69.25875  25.534669   1.0  50.00  65.0   80.0  255.0
# Attack      800.0  79.00125  32.457366   5.0  55.00  75.0  100.0  190.0
# Defense     800.0  73.84250  31.183501   5.0  50.00  70.0   90.0  230.0
# Sp. Atk     800.0  72.82000  32.722294  10.0  49.75  65.0   95.0  194.0
# Sp. Def     800.0  71.90250  27.828916  20.0  50.00  70.0   90.0  230.0
# Speed       800.0  68.27750  29.060474   5.0  45.00  65.0   90.0  180.0
# Generation  800.0   3.32375   1.661290   1.0   2.00   3.0    5.0    6.0

# %%
df.sort_values('Type 1', ascending = False)

df.sort_values(['Type 1','Speed'], ascending =[1,0]) # sorting multiple
# Out:
#                       Name Type 1   Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 291                Ninjask    Bug   Flying  61      90       45       50
# 15   BeedrillMega Beedrill    Bug   Poison  65     150       40       15
# 617               Accelgor    Bug      NaN  80      70       40      100
# 545              Scolipede    Bug   Poison  60     100       89       55
# 632                 Durant    Bug    Steel  58     109      112       48
# ..                     ...    ...      ...  ..     ...      ...      ...
# 199               Slowking  Water  Psychic  95      75       80      100
# 270                  Lotad  Water    Grass  40      30       30       40
# 564               Tirtouga  Water     Rock  54      78      103       53
# 79                Slowpoke  Water  Psychic  90      65       65       40
# 194                 Wooper  Water   Ground  55      45       45       25
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
# Making Changes to the Data
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']


# add unuse column

df['trial'] = df['Generation'] * 5

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  trial
# #
# 1       65     45           1      False    318      5
# 2       80     60           1      False    405      5
# 3      100     80           1      False    525      5
# 3      120     80           1      False    625      5
# 4       50     65           1      False    309      5

# %%
# dropping total and trial columns

df.drop(columns=['Total','trial'],inplace = True)

# %%
# better way to add new calculated column

df['Total'] = df.iloc[:, 3:9].sum( axis=1)

# %%
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# #
# ...

# %%
df.to_csv('modfied.csv')

# %%
# Filtering Data

df.loc[(df['Type 1']== 'Grass') & (df['Speed']>=80)]   # and operator

df.loc[(df['Type 2']== 'Fire') | (df['Type 1']=='Dark') & (df['HP']>100)]     # or operator

dew_df = df.loc[(df['Type 2']== 'Fire') | (df['Type 1']=='Dark') & (df['HP']>100)]

# %%
# filter on wildcard

df.loc[df['Name'].str.contains('Mega')]
# Out:
#                           Name    Type 1    Type 2   HP  Attack  Defense  \
# #
# 3        VenusaurMega Venusaur     Grass    Poison   80     100      123
# 6    CharizardMega Charizard X      Fire    Dragon   78     130      111
# 6    CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      BlastoiseMega Blastoise     Water       NaN   79     103      120
# 15       BeedrillMega Beedrill       Bug    Poison   65     150       40
# 18         PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 65       AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 80         SlowbroMega Slowbro     Water   Psychic   95      75      180
# 94           GengarMega Gengar     Ghost    Poison   60      65       80
# 115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 127          PinsirMega Pinsir       Bug    Flying   65     155      120
# 130      GyaradosMega Gyarados     Water      Dark   95     155      109
# ...

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# Aggregate Statistics

# %%
df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Defense', ascending= False)
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed  \
# Type 1
# Steel     65.222222   92.703704  126.370370  67.518519  80.629630   55.259259
# Rock      65.363636   92.863636  100.795455  63.340909  75.477273   55.909091
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Water     72.062500   74.151786   72.946429  74.812500  70.517857   65.964286
# Ice       72.000000   72.750000   71.416667  77.541667  76.291667   63.458333
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Poison    67.250000   74.678571   68.821429  60.428571  64.392857   63.571429
# ...

# %%
df.groupby('Type 1')['Attack'].sum()
# Out:
# Type 1
# Bug         4897
# Dark        2740
# Dragon      3588
# Electric    3040
# Fairy       1046
# Fighting    2613
# Fire        4408
# Flying       315
# Ghost       2361
# Grass       5125
# Ground      3064
# Ice         1746
# Normal      7200
# Poison      2091
# Psychic     4073
# Rock        4086
# Steel       2503
# Water       8305
# Name: Attack, dtype: int64

# %%
df.groupby(['Type 1','Type 2'])['Defense'].mean()
# Out:
# Type 1  Type 2
# Bug     Electric     55.000000
#         Fighting     95.000000
#         Fire         60.000000
#         Flying       61.571429
#         Ghost        45.000000
#                        ...
# Water   Ice         113.333333
#         Poison       58.333333
#         Psychic     104.000000
#         Rock        112.750000
#         Steel        88.000000
# Name: Defense, Length: 136, dtype: float64

# %%
df.groupby('Type 2')['HP'].count()
# Out:
# Type 2
# Bug          3
# Dark        20
# Dragon      18
# Electric     6
# Fairy       23
# Fighting    26
# Fire        12
# Flying      97
# Ghost       14
# Grass       25
# Ground      35
# Ice         14
# Normal       4
# Poison      34
# Psychic     33
# Rock        14
# Steel       22
# Water       14
# Name: HP, dtype: int64
